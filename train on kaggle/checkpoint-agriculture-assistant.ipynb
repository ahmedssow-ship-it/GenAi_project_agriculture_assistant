# %%
# Copier tout le dossier outputs vers /kaggle/working/
# !cp -r /kaggle/input/datasets/mumphone/mumphoneagriculture-qwen-checkpoint6500/agriculture_assistant /kaggle/working/

# %%
# !cp /kaggle/input/datasets/mumphone/eval-data/eval_allx.jsonl /kaggle/working/agriculture_assistant/data/splits

# %%
# !ls /kaggle/working/
# Out:
# agriculture_assistant  outputs

# %%
# %cd /kaggle/working/agriculture_assistant
# Out:
# /kaggle/working/agriculture_assistant

# %%
# !ls
# Out:
# build_chat_dataset.py	       prepare_data.py
# configs			       push_to_hub.py
# create_splits.py	       README.md
# data			       requirements.txt
# evaluation.py		       src
# hf_space		       templates
# inference_lora_qwen3_wolof.py  train_lora_assistant_only.py
# outputs

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.10.0+cu128)
# Requirement already satisfied: transformers>=4.45 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: accelerate>=0.33 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.13.0)
# Requirement already satisfied: datasets>=2.20 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.8.5)
# Requirement already satisfied: peft>=0.12 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (0.18.1)
# Collecting trl>=0.10 (from -r requirements.txt (line 6))
#   Downloading trl-1.6.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.3.3)
# Requirement already satisfied: typer>=0.12 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.24.1)
# Requirement already satisfied: huggingface_hub>=0.24 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.10.1)
# Requirement already satisfied: tensorboard>=2.16 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.19.0)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (3.10.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (2025.3.0)
# Collecting cuda-bindings==12.9.4 (from torch>=2.2->-r requirements.txt (line 1))
#   Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.2->-r requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45->-r requirements.txt (line 2)) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45->-r requirements.txt (line 2)) (26.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45->-r requirements.txt (line 2)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45->-r requirements.txt (line 2)) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45->-r requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45->-r requirements.txt (line 2)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.33->-r requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20->-r requirements.txt (line 4)) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20->-r requirements.txt (line 4)) (0.70.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 7)) (2026.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->-r requirements.txt (line 8)) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->-r requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->-r requirements.txt (line 8)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->-r requirements.txt (line 8)) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.24->-r requirements.txt (line 9)) (1.4.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.16->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.16->-r requirements.txt (line 10)) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.16->-r requirements.txt (line 10)) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.16->-r requirements.txt (line 10)) (5.29.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.16->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.16->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.16->-r requirements.txt (line 10)) (3.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 11)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 11)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 11)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (3.13.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20->-r requirements.txt (line 4)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20->-r requirements.txt (line 4)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20->-r requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.20->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.20->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=2.20->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.12->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.12->-r requirements.txt (line 8)) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.16->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20->-r requirements.txt (line 4)) (1.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.12->-r requirements.txt (line 8)) (0.1.2)
# Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 97.0 MB/s eta 0:00:00:00:0100:01
# Downloading trl-1.6.0-py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.1/825.1 kB 45.0 MB/s eta 0:00:00
# Installing collected packages: cuda-bindings, trl
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Successfully installed cuda-bindings-12.9.4 trl-1.6.0

# %%
# !pip check
# Out:
# bigframes 2.39.0 requires google-cloud-bigquery-storage, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage, which is not installed.
# ydata-profiling 4.18.4 has requirement numba<0.63,>=0.60, but you have numba 0.65.1.
# ydata-profiling 4.18.4 has requirement numpy<2.4,>=1.22, but you have numpy 2.4.6.
# google-colab 1.0.0 has requirement jupyter-server==2.14.0, but you have jupyter-server 2.12.5.
# google-colab 1.0.0 has requirement pandas==2.2.2, but you have pandas 2.3.3.
# dask-cuda 26.2.0 has requirement cuda-core==0.3.*, but you have cuda-core 1.0.1.
# dask-cuda 26.2.0 has requirement numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# dopamine-rl 4.1.2 has requirement gym<=0.25.2, but you have gym 0.26.2.
# distributed-ucxx-cu12 0.48.0 has requirement numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# moviepy 1.0.3 has requirement decorator<5.0,>=4.0.2, but you have decorator 5.3.1.
# cuml-cu12 26.2.0 has requirement numba<0.62.0,>=0.60.0, but you have numba 0.65.1.
# cuml-cu12 26.2.0 has requirement numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# ucxx-cu12 0.48.0 has requirement numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2.
# tensorflow 2.19.0 has requirement numpy<2.2.0,>=1.26.0, but you have numpy 2.4.6.
# cudf-cu12 26.2.1 has requirement numba<0.62.0,>=0.60.0, but you have numba 0.65.1.
# cudf-cu12 26.2.1 has requirement numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2.

# %%
# !python train_lora_assistant_only.py \
    --config configs/training_config_template.yml \
    --resume-from-checkpoint \
    /kaggle/working/outputs/qwen3_0_6b_wolof_lora/checkpoint-6500
# Out:
# Assistant-only training enabled.
# Labels are -100 for system/user/padding tokens; loss is only on assistant outputs.
# Training config: /kaggle/working/agriculture_assistant/configs/training_config_template.yml
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Training data: YAML training_data entries
# Output directory: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loaded 9000 rows from config source general: /kaggle/working/agriculture_assistant/data/splits/chat_general_train.json
# Loaded 4500 rows from config source synthetic: /kaggle/working/agriculture_assistant/data/splits/chat_synthetic_train.json
# Loaded 4500 rows from config source domain: /kaggle/working/agriculture_assistant/data/splits/chat_domain_train.json
# Tokenized examples: kept=18000, skipped=0, avg_total=256.1, avg_supervised=166.7, max_total=512, max_supervised=512
# Loaded 500 rows from config source general: /kaggle/working/agriculture_assistant/data/splits/chat_general_validation.json
# Loaded 250 rows from config source synthetic: /kaggle/working/agriculture_assistant/data/splits/chat_synthetic_validation.json
# Loaded 250 rows from config source domain: /kaggle/working/agriculture_assistant/data/splits/chat_domain_validation.json
# Validation examples: kept=1000, avg_supervised=169.1
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 981.99it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# trainable params: 10,092,544 || all params: 761,724,928 || trainable%: 1.3250
# 2026-06-13 13:39:49.074431: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781357989.096256     216 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781357989.103817     216 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781357989.123565     216 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781357989.123619     216 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781357989.123627     216 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781357989.123639     216 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Resuming from checkpoint: /kaggle/working/outputs/qwen3_0_6b_wolof_lora/checkpoint-6500
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# {'loss': '0.4672', 'grad_norm': '1.482', 'learning_rate': '3.189e-07', 'epoch': '2.893'}
# {'loss': '0.5697', 'grad_norm': '1.034', 'learning_rate': '2.93e-07', 'epoch': '2.898'}
# {'loss': '0.5393', 'grad_norm': '1.38', 'learning_rate': '2.682e-07', 'epoch': '2.902'}
# {'loss': '0.572', 'grad_norm': '1.297', 'learning_rate': '2.445e-07', 'epoch': '2.907'}
# {'loss': '0.5002', 'grad_norm': '1.15', 'learning_rate': '2.219e-07', 'epoch': '2.911'}
# {'loss': '0.5681', 'grad_norm': '1.208', 'learning_rate': '2.004e-07', 'epoch': '2.916'}
# {'loss': '0.6244', 'grad_norm': '1.063', 'learning_rate': '1.8e-07', 'epoch': '2.92'}
# {'loss': '0.4597', 'grad_norm': '1.295', 'learning_rate': '1.606e-07', 'epoch': '2.924'}
# {'loss': '0.5314', 'grad_norm': '1.201', 'learning_rate': '1.424e-07', 'epoch': '2.929'}
# {'loss': '0.551', 'grad_norm': '1.694', 'learning_rate': '1.253e-07', 'epoch': '2.933'}
# {'loss': '0.6283', 'grad_norm': '4.519', 'learning_rate': '1.092e-07', 'epoch': '2.938'}
# {'loss': '0.5525', 'grad_norm': '1.412', 'learning_rate': '9.43e-08', 'epoch': '2.942'}
# {'loss': '0.4214', 'grad_norm': '0.8339', 'learning_rate': '8.045e-08', 'epoch': '2.947'}
# {'loss': '0.4687', 'grad_norm': '1.484', 'learning_rate': '6.771e-08', 'epoch': '2.951'}
# {'loss': '0.5322', 'grad_norm': '1.505', 'learning_rate': '5.606e-08', 'epoch': '2.956'}
# {'loss': '0.5939', 'grad_norm': '1.35', 'learning_rate': '4.551e-08', 'epoch': '2.96'}
# {'loss': '0.4812', 'grad_norm': '1.03', 'learning_rate': '3.606e-08', 'epoch': '2.964'}
# {'loss': '0.5019', 'grad_norm': '1.003', 'learning_rate': '2.771e-08', 'epoch': '2.969'}
# {'loss': '0.5994', 'grad_norm': '1.136', 'learning_rate': '2.045e-08', 'epoch': '2.973'}
# {'loss': '0.551', 'grad_norm': '1.128', 'learning_rate': '1.43e-08', 'epoch': '2.978'}
# {'loss': '0.5949', 'grad_norm': '1.094', 'learning_rate': '9.239e-09', 'epoch': '2.982'}
# {'loss': '0.5262', 'grad_norm': '1.811', 'learning_rate': '5.282e-09', 'epoch': '2.987'}
# {'loss': '0.5172', 'grad_norm': '2.925', 'learning_rate': '2.424e-09', 'epoch': '2.991'}
# {'loss': '0.5352', 'grad_norm': '1.316', 'learning_rate': '6.651e-10', 'epoch': '2.996'}
# {'loss': '0.6152', 'grad_norm': '1.201', 'learning_rate': '5.497e-12', 'epoch': '3'}
# {'train_runtime': '1432', 'train_samples_per_second': '37.71', 'train_steps_per_second': '4.713', 'train_loss': '0.02', 'epoch': '3'}
# 100%|███████████████████████████████████████| 6750/6750 [23:52<00:00,  4.71it/s]
# Saved LoRA adapter and tokenizer to /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora
# Saved training history and curves to /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora
# TensorBoard logs: /kaggle/working/agriculture_assistant/outputs/tensorboard/qwen3_0_6b_wolof_lora
# Loading weights: 100%|█| 311/311 [00:00<00:00, 660.53it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 655.51it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 653.26it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 658.47it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 664.60it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 648.89it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 662.13it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 648.00it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 656.43it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Loading weights: 100%|█| 311/311 [00:00<00:00, 655.73it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/5...
# Generating prediction 2/5...
# Generating prediction 3/5...
# Generating prediction 4/5...
# Generating prediction 5/5...
# Kept checkpoints: ['checkpoint-6750', 'checkpoint-6500', 'checkpoint-6000', 'checkpoint-5500', 'checkpoint-4500']
# Removed checkpoints: ['checkpoint-2000', 'checkpoint-2500', 'checkpoint-3500', 'checkpoint-4000', 'checkpoint-5000']
# Best checkpoint by evaluation: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/checkpoint-6750
# Clean best adapter export: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# Latest checkpoint export: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/latest_adapter

# %%
# !python evaluation.py \
  --data data/splits/eval_allx.jsonl \
  --generate \
  --model-choice qwen \
  --adapter auto
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 687.16it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Generating prediction 1/200...
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating prediction 2/200...
# Generating prediction 3/200...
# Generating prediction 4/200...
# Generating prediction 5/200...
# Generating prediction 6/200...
# Generating prediction 7/200...
# Generating prediction 8/200...
# Generating prediction 9/200...
# Generating prediction 10/200...
# Generating prediction 11/200...
# Generating prediction 12/200...
# Generating prediction 13/200...
# Generating prediction 14/200...
# Generating prediction 15/200...
# Generating prediction 16/200...
# Generating prediction 17/200...
# Generating prediction 18/200...
# Generating prediction 19/200...
# Generating prediction 20/200...
# Generating prediction 21/200...
# Generating prediction 22/200...
# Generating prediction 23/200...
# Generating prediction 24/200...
# Generating prediction 25/200...
# Generating prediction 26/200...
# Generating prediction 27/200...
# Generating prediction 28/200...
# Generating prediction 29/200...
# Generating prediction 30/200...
# Generating prediction 31/200...
# Generating prediction 32/200...
# Generating prediction 33/200...
# Generating prediction 34/200...
# Generating prediction 35/200...
# Generating prediction 36/200...
# Generating prediction 37/200...
# Generating prediction 38/200...
# Generating prediction 39/200...
# Generating prediction 40/200...
# Generating prediction 41/200...
# Generating prediction 42/200...
# Generating prediction 43/200...
# Generating prediction 44/200...
# Generating prediction 45/200...
# Generating prediction 46/200...
# Generating prediction 47/200...
# Generating prediction 48/200...
# Generating prediction 49/200...
# Generating prediction 50/200...
# Generating prediction 51/200...
# Generating prediction 52/200...
# Generating prediction 53/200...
# Generating prediction 54/200...
# Generating prediction 55/200...
# Generating prediction 56/200...
# Generating prediction 57/200...
# Generating prediction 58/200...
# Generating prediction 59/200...
# Generating prediction 60/200...
# Generating prediction 61/200...
# Generating prediction 62/200...
# Generating prediction 63/200...
# Generating prediction 64/200...
# Generating prediction 65/200...
# Generating prediction 66/200...
# Generating prediction 67/200...
# Generating prediction 68/200...
# Generating prediction 69/200...
# Generating prediction 70/200...
# Generating prediction 71/200...
# Generating prediction 72/200...
# Generating prediction 73/200...
# Generating prediction 74/200...
# Generating prediction 75/200...
# Generating prediction 76/200...
# Generating prediction 77/200...
# Generating prediction 78/200...
# Generating prediction 79/200...
# Generating prediction 80/200...
# Generating prediction 81/200...
# Generating prediction 82/200...
# Generating prediction 83/200...
# Generating prediction 84/200...
# Generating prediction 85/200...
# Generating prediction 86/200...
# Generating prediction 87/200...
# Generating prediction 88/200...
# Generating prediction 89/200...
# Generating prediction 90/200...
# Generating prediction 91/200...
# Generating prediction 92/200...
# Generating prediction 93/200...
# Generating prediction 94/200...
# Generating prediction 95/200...
# Generating prediction 96/200...
# Generating prediction 97/200...
# Generating prediction 98/200...
# Generating prediction 99/200...
# Generating prediction 100/200...
# Generating prediction 101/200...
# Generating prediction 102/200...
# Generating prediction 103/200...
# Generating prediction 104/200...
# Generating prediction 105/200...
# Generating prediction 106/200...
# Generating prediction 107/200...
# Generating prediction 108/200...
# Generating prediction 109/200...
# Generating prediction 110/200...
# Generating prediction 111/200...
# Generating prediction 112/200...
# Generating prediction 113/200...
# Generating prediction 114/200...
# Generating prediction 115/200...
# Generating prediction 116/200...
# Generating prediction 117/200...
# Generating prediction 118/200...
# Generating prediction 119/200...
# Generating prediction 120/200...
# Generating prediction 121/200...
# Generating prediction 122/200...
# Generating prediction 123/200...
# Generating prediction 124/200...
# Generating prediction 125/200...
# Generating prediction 126/200...
# Generating prediction 127/200...
# Generating prediction 128/200...
# Generating prediction 129/200...
# Generating prediction 130/200...
# Generating prediction 131/200...
# Generating prediction 132/200...
# Generating prediction 133/200...
# Generating prediction 134/200...
# Generating prediction 135/200...
# Generating prediction 136/200...
# Generating prediction 137/200...
# Generating prediction 138/200...
# Generating prediction 139/200...
# Generating prediction 140/200...
# Generating prediction 141/200...
# Generating prediction 142/200...
# Generating prediction 143/200...
# Generating prediction 144/200...
# Generating prediction 145/200...
# Generating prediction 146/200...
# Generating prediction 147/200...
# Generating prediction 148/200...
# Generating prediction 149/200...
# Generating prediction 150/200...
# Generating prediction 151/200...
# Generating prediction 152/200...
# Generating prediction 153/200...
# Generating prediction 154/200...
# Generating prediction 155/200...
# Generating prediction 156/200...
# Generating prediction 157/200...
# Generating prediction 158/200...
# Generating prediction 159/200...
# Generating prediction 160/200...
# Generating prediction 161/200...
# Generating prediction 162/200...
# Generating prediction 163/200...
# Generating prediction 164/200...
# Generating prediction 165/200...
# Generating prediction 166/200...
# Generating prediction 167/200...
# Generating prediction 168/200...
# Generating prediction 169/200...
# Generating prediction 170/200...
# Generating prediction 171/200...
# Generating prediction 172/200...
# Generating prediction 173/200...
# Generating prediction 174/200...
# Generating prediction 175/200...
# Generating prediction 176/200...
# Generating prediction 177/200...
# Generating prediction 178/200...
# Generating prediction 179/200...
# Generating prediction 180/200...
# Generating prediction 181/200...
# Generating prediction 182/200...
# Generating prediction 183/200...
# Generating prediction 184/200...
# Generating prediction 185/200...
# Generating prediction 186/200...
# Generating prediction 187/200...
# Generating prediction 188/200...
# Generating prediction 189/200...
# Generating prediction 190/200...
# Generating prediction 191/200...
# Generating prediction 192/200...
# Generating prediction 193/200...
# Generating prediction 194/200...
# Generating prediction 195/200...
# Generating prediction 196/200...
# Generating prediction 197/200...
# Generating prediction 198/200...
# Generating prediction 199/200...
# Generating prediction 200/200...
#
# === Aggregate metrics ===
#     exact_match: 0.1350
#        token_f1: 0.4125
#            bleu: 0.2697
#         rouge_l: 0.3675
#
# === Example-level scores ===
#
# [1] category=
# Q: INSTRUCTION: Summarize the following passage.
# PASSAGE: "This is the master list! A load of farm blogs I love to check out — all in alphabetical order based on the title of the blog! Feel free to browse, starting and stopping at your leisure — maybe start with the first letter of your name, cause it is fun to spread the love around a little bit! If you have a specific crop or geography, you may want to use find in your browser to help. IF YOU WANT TO BE ADDED: I enjoy checking out new blogs and add them now and then. Please fill out the form below the Zs (not commenting as I want to be sure I get some key info to review). Adding them is a bit subjective on my part — so far I’ve added most everyone who has asked but remember, I like positivity not negativity."
# Reference:  RESPONSE: Strategy for Summarizing a Passage
#
# ### Summarized Response Using the Strategy:
#
# **1. Understand the Passage:** The passage is an announcement-style text that lists a collection of farm blogs in alphabetical order, inviting readers to explore them.
#
# **2. Identify the Structure:**
# - **Transitions**: The passage uses phrases like "Feel free to browse" and "If you have a specific crop or geography" to guide the reader.
# - **Type of Passage**: Informative and list-based, aimed at sharing a collection of farm blogs.
#
# **3. Determine the Core Message:** The passage presents a list of farm blogs in alphabetical order, encouraging readers to explore them and provides information on how to suggest new blogs for inclusion.
#
# **4. Write the Summary:**
# A list of farm blogs is provided in alphabetical order, allowing readers to browse and explore their interests. Readers can also suggest new blogs for inclusion by filling out a form, with the author prioritizing positivity and subjective selection.
#
# **5. Review and Edit:**
# - The summary captures the main idea of the passage without minor details.
# - Language is clear and concise.
# - Reflects the essence of the original passage without altering its meaning.
#
# ### FINAL RESPONSE: A list of farm blogs is available in alphabetical order for readers to explore, and suggestions for new blogs can be made by filling out a form, with a focus on positivity and subjective selection.
# Prediction: RESPONSE: Strategy for Summarizing a Passage
#
# ### Summarized Response Using the Strategy:
#
# **1. Understand the Passage:** The passage is an announcement-style text that invites readers to explore a collection of farm-related blogs in alphabetical ordering.
#
# **2. Identify the Structure:**
# - **Transitions**: The passage uses phrases like "Feel free to..." and "IF YOU WANT" to guide the reader through the process of adding new blogs.
# - **Type of Passage**: Informative and invitation-based, aimed at encouraging exploration and engagement with farm blogs.
#
# **3. Determine the Core Message:** The core message is an invitation to explore and discover new farm blogs, while also providing instructions on how to submit new entries.
#
# **4. Write the Summary:**
# A collection of top farm blogs
# Scores: EM=0.00, F1=0.57, BLEU=0.22, ROUGE-L=0.48
#
# [2] category=
# Q: how can distinguish female from male
# Reference:  Females and males can be distinguished by the number of bristles on their frenulum
# Prediction: Females and males can be distinguished by the number of bristles on their frenulum
# Scores: EM=1.00, F1=1.00, BLEU=1.00, ROUGE-L=1.00
#
# [3] category=
# Q: INSTRUCTION: Read the following passage and answer the question based on it.
# PASSAGE: Beef Runner is a blog that provides blog topic ideas for agriculture bloggers, including topics related to the beef industry. The blog's author, Ryan Goodman, has a lifetime of experience in agriculture and has worked with family farms, ranches, and large feedlots. He is also an avid mountain and trail runner.
# Question: Is it true that Ryan Goodman's experience in the beef industry ranges from family farms to large feedlots?
# Reference:  **Step-by-Step Solution:
# 1. **Read and Understand the Passage**: The passage describes Ryan Goodman's experience in the beef industry, mentioning that he has worked with family farms, ranches, and large feedlots.
# 2. **Evaluate the Central Claim of Question**: The question asks whether Ryan Goodman's experience in the beef industry ranges from family farms to large feedlots.
# 3. **Identify Key Components w.r.t Claim from the Passage**: The passage explicitly states that Ryan Goodman has experience working with family farms, ranches, and large feedlots.
# 4. **Compare the Central Claim with Key Component:**: The passage directly mentions that Ryan Goodman's experience in the beef industry includes working with family farms, ranches, and large feedlots. This directly supports the claim that his experience ranges from family farms to large feedlots.
# 5. **Conclusion**: Since the passage directly states that Ryan Goodman has experience working with family farms, ranches, and large feedlots, the answer to the question is **TRUE**.
#
#  CORRECT OPTION: TRUE.
# Prediction: **Step-by-Step Solution:
# 1. **Read and Understand the Passage**: The passage describes Ryan Goodman as having a diverse range of experiences in the agriculture sector.
# 2. **Evaluate the Central Claim of Question**: The question asks whether Ryan Goodman’s experience in his field spans from family farm to large cattle operations.
# 3. **Identify Key Components w.r.t Claim from the Passage:** The passage mentions that Ryan has "worked with family Farms" and "large Feedlots," which suggests that he has experience working with different types of farms or cattle operations, but does not explicitly state that this includes large cattle operation.
# 4. **Compare the Central Claim with Key Component:** Although the passage does mention large feedlot, it does not provide enough information to confirm that this type of experience is included
# Scores: EM=0.00, F1=0.61, BLEU=0.37, ROUGE-L=0.50
#
# [4] category=
# Q: INSTRUCTION: Answer the following question.
# PASSAGE: Imagine a world where your consumer can scan a QR code on an apple and see its journey. From the orchard where it grew to the truck that delivered it to the grocery store, they get access to all the data. No more questions about the use of pesticides or fertilizers. No more wondering about fair trade practices. The consumer will know as much about the process of growing that apple as you! This level of transparency and traceability is possible now because of blockchain in agriculture. Did you know that only 44% of global consumers trust the food industry to act ethically? The need for transparency and traceability in the agriculture industry has never been greater! As the world explores the use of blockchain technology in agriculture, let us take a quick peek at it, too. In this blog, we’ll cover how blockchain has increased traceability and transparency in agricultural practices and how it has improved food safety for consumers and producers. The use of blockchain technology to address traceability issues has dramatically increased over the years. In this context, the term “traceability” refers to the capability of following the path of agricultural products from their place of origin on the farm to their final destination on consumers’ plates–every stage of the process is involved, from planting and harvesting to processing, packaging, and distribution. Traceability holds immense significance in the agricultural sector, and its importance cannot be overstated for several compelling reasons. Some of them are: The idea of having safe food is not new. However, over the decades, the gap between producers’ and consumers’ knowledge about food has increased. This is one reason why the need to ensure the safety of the food has increased. With Blockchain, consumers can have a tamper-proof ledger of each stage in the supply chain. This enables quick identification and correction of any issue related to their food. Today’s consumers are becoming increasingly aware of the food they consume. They are interested in its origin, cultivation methods, and compliance with moral and environmental standards. Blockchain traceability gives consumers the information they want and increases consumer confidence in the food supply chain. For those looking to diversify their investments, opportunities like those to buy bitcoin with debit card can represent a modern approach to finance, blending traditional practices with new technological integrations. Supply networks are more effective when traceability is improved. By utilizing the data gathered through blockchain, farmers can more effectively manage their resources, cut down on waste, and increase agricultural yields. Fair labor procedures and sustainable farming techniques are two ethical issues in agriculture that are gaining ground. Blockchain makes it possible to validate these procedures, assuring customers that the things they buy are consistent with their beliefs. A robust traceability system can open doors to new markets for producers. Many retailers and distributors now require traceability data for their sourcing criteria. “Farm-to-fork traceability” allows the tracking and tracing of agricultural products from their place of origin to the consumer’s plate. For this to work, every stage of the blockchain in the agriculture supply chain must be documented and monitored. This idea is important to agriculture because it guarantees responsibility and openness throughout a food product’s lifecycle. Farm-to-fork traceability is highly relevant to the agriculture industry for several reasons. One of them is food safety. By quickly identifying and containing tainted or dangerous items, traceability shields customers from possible health concerns. Another reason is the traceability factor, which allows farmers and other producers to uphold stringent quality control standards. They may track and record variables like weather patterns, soil quality, and pest control, assuring the development ...
# Reference:  RESPONSE: Step-by-Step Solution:
#
# 1. Understand the Problem Context:
#  Main Theme: The question asks for the three main benefits of using blockchain technology in agriculture and how they impact the food supply chain.
# Constraints:
# - The response must be in three bullet points.
# - The entire answer should be in uppercase letters.
# - The response must be written in a formal tone.
#
# 2. Clarify the Constraints:
# - The answer must be divided into three distinct bullet points, each highlighting a benefit of using blockchain technology in agriculture.
# - The response must be written in uppercase letters.
# - The response should address the benefits of blockchain technology in the context of the food supply chain.
#
# 3. Analyze the Objective:
# - The goal is to identify the three main benefits of using blockchain technology in agriculture and explain how they impact the food supply chain.
# - The response should focus on the advantages of blockchain technology in the agricultural industry.
#
# 4. Understand the PASSAGE:
# - The PASSAGE highlights the benefits of blockchain technology in agriculture, including increased transparency, improved food safety, and enhanced traceability.
#
# 5. Plan Your Response:
# - Bullet Point 1: Highlight the benefit of increased transparency in the food supply chain.
# - Bullet Point 2: Explain how blockchain technology improves food safety in the agricultural industry.
# - Bullet Point 3: Discuss the advantage of enhanced traceability in the food supply chain.
#
# 6. Generate the Response:
# - Draft the response in uppercase letters, using bullet points to highlight the three benefits of blockchain technology in agriculture.
#
# 7. Evaluate Against Constraints:
# - Ensure that the response is divided into three bullet points, all text is in uppercase letters, and the response is written in a formal tone.
#
# 8. Refine and Finalize:
# - Review the response for clarity, conciseness, and adherence to the constraints.
#
# FINAL RESPONSE:
# THE THREE MAIN BENEFITS OF USING BLOCKCHAIN TECHNOLOGY IN AGRICULTURE ARE:
# • **INCREASED TRANSPARENCY**: BLOCKCHAIN TECHNOLOGY PROVIDES REAL-TIME VISIBILITY AND ACCOUNTABILITY IN THE FOOD SUPPLY CHAIN, ALLOWING CONSUMERS TO ACCESS INFORMATION ABOUT THE ORIGIN, CULTIVATION METHODS, AND COMPLIANCE WITH MORAL AND ENVIRONMENTAL STANDARDS OF THE PRODUCTS THEY CONSUME.
# • **IMPROVED FOOD SAFETY**: BLOCKCHAIN TECHNOLOGY ENHANCES FOOD SAFETY IN THE AGRICULTURAL INDUSTRY BY PROVIDING A TAMPER-PROOF LEDGER OF EACH STAGE IN THE SUPPLY CHAIN, ENABLING QUICK IDENTIFICATION AND CORRECTION OF ANY ISSUE RELATED TO FOOD.
# • **ENHANCED TRACEABILITY**: BLOCKCHAIN TECHNOLOGY FACILITATES SWIFT RESOLUTION OF FOOD SAFETY COMPLIANCE CONCERNS, FOOD CONTAMINATION, OR PRODUCT RECALLS BY PROVIDING ALL RELEVANT DATA, ENABLING STAKEHOLDERS TO IDENTIFY SOURCES, ISOLATE AFFECTED PRODUCTS, AND INFORM CONSUMERS.
# Prediction: RESPONSE: Step-by-Step Solution:
#
# 1. Understand the Problem Context:
#  Main Theme: The benefits of blockchain tech in agriculture.
#
# 2. Clarify the Constraints:
# - Type of Content: Informative and factual.
# - Tone: Formal and engaging.
# - Length: Concise but comprehensive.
# - Constraints: Use bullet points and adhere to the specified rules.
#
# 3. Analyze the Objective:
# - Goal: Identify the three primary benefits of adopting blockchain technology for agriculture and explain how they impact food supplychains.
#
# 4. Plan Your Response:
# - List the three benefits of区块链技术 in agriculture.
# - Explain how each benefit impacts the foodsupplychain.
#
# 5. Generate the Response:
# • Benefits of Blockchain Technology in Agriculture:
# • Improved Food Safety: Blockchain provides real-time transparency and accountability, helping to prevent
# Scores: EM=0.00, F1=0.34, BLEU=0.03, ROUGE-L=0.27
#
# [5] category=
# Q: INSTRUCTION: Replace the masked words with the correct words from the content.
# Question: Precision mapping combines advanced data layers like {{ DET }} composition, {{ NOUN }} health, and {{ NOUN }} elevation with autonomous technology to revolutionize modern {{ NOUN }}.
# Options: [soil, crop, terrain, agriculture]
# Reference:  RESPONSE: Step-by-Step Strategy:
#
# 1. **Go through the options and roughly decide the possible POS tags for each option:**
# - soil: likely a NOUN (a type of earth material).
# - crop: likely a NOUN (a plant cultivated for food).
# - terrain: likely a NOUN (the physical features of an area).
# - agriculture: likely a NOUN (the practice of farming).
#
# 2. Read the Passage Thoroughly:**
# - The passage talks about the key components of precision mapping, including soil composition, crop health, and terrain elevation.
#
# 3. **Identify the correct POS tags for the Options:**
# - soil fits as a noun because it refers to a type of earth material.
# - crop fits as a noun because it refers to a plant cultivated for food.
# - terrain fits as a noun because it refers to the physical features of an area.
# - agriculture fits as a noun because it refers to the practice of farming.
#
# 4. **Fill the Masked Words:**
# - The first masked word corresponds to a type of earth material, which is **soil**.
# - The second masked word refers to the health of a plant, which is **crop**.
# - The next masked word should be related to the physical features of an area, which is **terrain**.
# - The last masked word is related to the practice of farming, which would be **agriculture**.
#
# 5. **Ensure Agreement with the Sentence:**
# - The sentence structure is clear, and the words fit logically and grammatically. The nouns align well with the context of precision mapping.
#
# 6. **Double-Check for Multiple Possibilities:**
# - The words provided match the context perfectly. There are no alternatives that fit better in this case.
#
# FINAL RESPONSE: CORRECT OPTIONS: [soil, crop, terrain, agriculture]
# ANSWER: Precision mapping combines advanced data layers like soil composition, crop health, and terrain elevation with autonomous technology to revolutionize modern agriculture.
# Prediction: RESPONSE: Step-by-Step Strategy:
#
# 1. **Go through the options and roughly decide the possible POS tags for each option:**
# - soil: likely a NOUN (a type of land).
# - crop: likely an ADJ or NOUN.
# - terrain: likely NOUN or possibly a PROPN (a geographical feature).
# - agriculture: likely VERB.
#
# 2. Read the Passage Thoroughly:**
# - The passage talks about precision mapping combining various data layers and technologies to revolutionise modern agriculture.
#
# 3. **Identify the correct POS tagsfor the Options:**
# -[crop] fits as an adjective modifying "health," but it's not directly related to the context of precision mapping.
# [terrain] is used as a noun, referring to a geographical feature.
# [aug
# Scores: EM=0.00, F1=0.41, BLEU=0.09, ROUGE-L=0.34
#
# [6] category=
# Q: INSTRUCTION: Question: I'm interested in organizing a Farm to Table meal in my community, but I'm not sure where to start. What are the key considerations and steps I should take to bring together local food advocates and host a successful event that supports area farms and farmers markets?
# Reference:  RESPONSE: Step-by-Step Reasoning
#
# 1. Identify the Problem or Situation:
# - Problem: You want to organize a Farm to Table meal in your community but are unsure about the key considerations and steps to take.
#
# 2. Clarify the Type of Guidance Needed:
# - You are seeking information on the key considerations and steps to organize a successful Farm to Table meal that supports area farms and farmers markets.
#
# 3. Provide a Concise Title:
# Title: "Organizing a Successful Farm to Table Meal: A Step-by-Step Guide"
#
# 4. Ask Clear, Specific Questions:
# - What are the key considerations for organizing a Farm to Table meal in my community?
# - How can I bring together local food advocates to support the event?
# - What are the essential steps to host a successful Farm to Table meal that benefits area farms and farmers markets?
#
# 5. Request Actionable Insights or Strategies:
# - What are the key factors to consider when selecting a venue and menu for the event?
# - How can I engage local farmers and food producers to participate in the event?
# - What are some effective ways to promote the event and attract attendees?
#
# 6. Understand the Implications:
# - How can a Farm to Table meal positively impact the local food system and support area farms and farmers markets?
# - What are the potential challenges and limitations of organizing such an event, and how can they be overcome?
#
# FINAL RESPONSE:
#
# FINAL RESPONSE: Step by Step Reasoning.
#
# 1. Key Considerations:
# - Identify a clear purpose and goal for the event, such as supporting local farmers or promoting sustainable agriculture.
# - Build a team of local food advocates, including farmers, chefs, and community leaders, to help plan and execute the event.
# - Choose a venue that is easily accessible and can accommodate the number of attendees you expect.
#
# 2. Bringing Together Local Food Advocates:
# - Reach out to local farmers, food producers, and community organizations to invite them to participate in the event.
# - Engage with local chefs and restaurants to secure their involvement in the event, either as participants or sponsors.
# - Utilize social media and local newspapers to promote the event and attract attendees.
#
# 3. Essential Steps to Host a Successful Event:
# - Plan a menu that showcases local and seasonal ingredients, and consider partnering with local farmers to source ingredients.
# - Develop a marketing strategy to promote the event, including social media, flyers, and local advertising.
# - Ensure that the event is well-organized and runs smoothly, with a clear schedule and adequate staffing.
#
# 4. Key Factors to Consider:
# - Choose a venue that is easily accessible and can accommodate the number of attendees you expect.
# - Select a menu that is appealing to a wide range of tastes and dietary needs.
# - Engage with local farmers and food producers to ensure that they are involved in the event and are able to showcase their products.
#
# 5. Effective Ways to Promote the Event:
# - Utilize social media to promote the event and attract attendees.
# - Partner with local businesses and organizations to secure sponsorships and promote the event.
# - Create eye-catching flyers and posters to distribute in local areas.
#
# 6. Positive Impact on the Local Food System:
# - A Farm to Table meal can help promote local food systems and support area farms and farmers markets by providing a platform for local food producers to showcase their products.
# - The event can also help raise awareness about the importance of sustainable agriculture and the benefits of buying local.
#
# 7. Potential Challenges and Limitations:
# - One potential challenge is securing the involvement of local farmers and food producers, as they may have competing demands on their time and resources.
# - Another challenge is ensuring that the event is well-organized and runs smoothly, with a clear schedule and adequate staffing.
# Prediction: RESPONSE: Step-by-Step Plan.
#
# 1. Understand the Core Objective of the Question: The goal is to organize a Farm-to-Table meal in a community while involving local food activists and supporting local farms and markets.
#
# 2. Break Down the Problem Into Key Components:
# - Community Engagement: How to connect with local food organizations and advocates?
# - Event Planning: What are essential elements for a successful Farm-to-table event?
# - Resource Utilization: Where can I find information on local farms, markets, and resources?
#
# 3. Propose Concrete Strategies:
# Community Building: Start by reaching out to local food groups, restaurants, and businesses to learn about their offerings and interests. Attend town halls or meetups to network and establish connections.
# Event Planning: Organize a Foodie Friday or Harvest
# Scores: EM=0.00, F1=0.23, BLEU=0.00, ROUGE-L=0.15
#
# [7] category=
# Q: What are some common coconut varieties suitable for cultivation?
# Reference:  Common coconut varieties include Tall, Dwarf, and Hybrid varieties such as Malayan Dwarf, West African Tall, and Pacific Tall, among others. Varieties vary in growth habit, nut size, yield, and tolerance to specific environmental conditions, allowing growers to choose based on local climate, soil type, and intended use (copra production, coconut water, or fresh consumption).
# Prediction: Common coconut varieties include:
# - Coconut (Narus davidii)
# - Coconut nucy (Nicus indica)
# - Pongamia panica
# - Acacia nilotica
# Coconut palms can be grown in various climates, including tropical and subtropical regions. They thrive well in areas with high humidity and warm temperatures.
# Scores: EM=0.00, F1=0.17, BLEU=0.07, ROUGE-L=0.15
#
# [8] category=
# Q: INSTRUCTION: Fill in the blanks:
# PASSAGE: Regenerative agriculture offers a unique approach to farming that restores ecosystems, enhances resilience to climate change, and fosters sustainable development. In this approach, farmers use practices such as crop rotation, cover cropping, and integrating livestock grazing to improve soil health and biodiversity. Regenerative agriculture also promotes the use of organic amendments and efficient irrigation systems to minimize the use of synthetic fertilizers and pesticides. By adopting these practices, farmers can improve crop yields, reduce their environmental impact, and increase their income.
# Question: Regenerative agriculture involves the use of __________ and __________ to improve soil health and biodiversity.
# Reference:  **Step-by-Step Solution:**
#
# 1. **Understand the Passage**: The passage describes the practices involved in regenerative agriculture, including crop rotation, cover cropping, and integrating livestock grazing.
#
# 2. **Identify the Keywords around the blanks in the question**:
#  - **Blank 1**: The question mentions "use of" and "improve soil health and biodiversity," which points to a practice that is used to improve soil health.
# - **Blank 2**: The question mentions "use of" and "improve soil health and biodiversity," which points to another practice that is used to improve soil health and biodiversity.
#
# 3. **Extract Information from the Passage answering Step 2**:
# - For Blank 1: The passage clearly states that farmers use practices such as **crop rotation** to improve soil health and biodiversity.
# - For Blank 2: The passage specifies that farmers also use **cover cropping** to improve soil health and biodiversity.
#
# 4. **Evaluate the Context and Retrieved Information**:
# - Blank 1 must be filled with **crop rotation** because that is one of the practices used to improve soil health and biodiversity.
# - Blank 2 must be filled with **cover cropping** because that is another practice used to improve soil health and biodiversity.
#
# 5. **Conclusion**:  The first blank is filled with **crop rotation**, and the second blank is filled with **cover cropping**.
#
#  FINAL RESPONSE: crop rotation, cover cropping
# Prediction: **Step-by-Step Solution:**
#
# 1. **Understand the Passage**: The passage describes the key practices involved in regenerative agriculture, including crop rotation and cover cropping.
#
# 2. **Identify the Keywords around the blanks in the question**:
#  - **Blank 1**: The question mentions "use" and "improve," which points to a practice used in regenerating agriculture.
# - **Blank2**: The phrase "improves" suggests that the second practice is related to improving soil health or biodiversity.
#
# 3. **Extract Information from the Passage answering Step 2**:
# - For Blank 1: The passage clearly states that farmers use **crop rotation** to improve crop yield and soil health.
# - For blank2: The next blank refers to the practice of **cover cropping**,
# Scores: EM=0.00, F1=0.58, BLEU=0.23, ROUGE-L=0.53

# %%
# !python evaluation.py \
  --data data/splits/eval_all.jsonl \
  --generate \
  --model-choice qwen \
  --adapter auto
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 690.66it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Generating prediction 1/1000...
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating prediction 2/1000...
# Generating prediction 3/1000...
# Generating prediction 4/1000...
# Generating prediction 5/1000...
# Generating prediction 6/1000...
# Generating prediction 7/1000...
# Generating prediction 8/1000...
# Generating prediction 9/1000...
# Generating prediction 10/1000...
# Generating prediction 11/1000...
# Generating prediction 12/1000...
# Generating prediction 13/1000...
# Generating prediction 14/1000...
# Generating prediction 15/1000...
# Generating prediction 16/1000...
# Generating prediction 17/1000...
# Generating prediction 18/1000...
# Generating prediction 19/1000...
# Generating prediction 20/1000...
# Generating prediction 21/1000...
# Generating prediction 22/1000...
# Generating prediction 23/1000...
# Generating prediction 24/1000...
# Generating prediction 25/1000...
# Generating prediction 26/1000...
# Generating prediction 27/1000...
# Generating prediction 28/1000...
# Generating prediction 29/1000...
# Generating prediction 30/1000...
# Generating prediction 31/1000...
# Generating prediction 32/1000...
# Generating prediction 33/1000...
# Generating prediction 34/1000...
# Generating prediction 35/1000...
# Generating prediction 36/1000...
# Generating prediction 37/1000...
# Generating prediction 38/1000...
# Generating prediction 39/1000...
# Generating prediction 40/1000...
# Generating prediction 41/1000...
# Generating prediction 42/1000...
# Generating prediction 43/1000...
# Generating prediction 44/1000...
# Generating prediction 45/1000...
# Generating prediction 46/1000...
# Generating prediction 47/1000...
# Generating prediction 48/1000...
# Generating prediction 49/1000...
# Generating prediction 50/1000...
# Generating prediction 51/1000...
# Generating prediction 52/1000...
# Generating prediction 53/1000...
# Generating prediction 54/1000...
# Generating prediction 55/1000...
# Generating prediction 56/1000...
# Generating prediction 57/1000...
# Generating prediction 58/1000...
# Generating prediction 59/1000...
# Generating prediction 60/1000...
# Generating prediction 61/1000...
# Generating prediction 62/1000...
# Generating prediction 63/1000...
# Generating prediction 64/1000...
# Generating prediction 65/1000...
# Generating prediction 66/1000...
# Generating prediction 67/1000...
# Generating prediction 68/1000...
# Generating prediction 69/1000...
# Generating prediction 70/1000...
# Generating prediction 71/1000...
# Generating prediction 72/1000...
# Generating prediction 73/1000...
# Generating prediction 74/1000...
# Generating prediction 75/1000...
# Generating prediction 76/1000...
# Generating prediction 77/1000...
# Generating prediction 78/1000...
# Generating prediction 79/1000...
# Generating prediction 80/1000...
# Generating prediction 81/1000...
# Generating prediction 82/1000...
# Generating prediction 83/1000...
# Generating prediction 84/1000...
# Generating prediction 85/1000...
# Generating prediction 86/1000...
# Generating prediction 87/1000...
# Generating prediction 88/1000...
# Generating prediction 89/1000...
# Generating prediction 90/1000...
# Generating prediction 91/1000...
# Generating prediction 92/1000...
# Generating prediction 93/1000...
# Generating prediction 94/1000...
# Generating prediction 95/1000...
# Generating prediction 96/1000...
# Generating prediction 97/1000...
# Generating prediction 98/1000...
# Generating prediction 99/1000...
# Generating prediction 100/1000...
# Generating prediction 101/1000...
# Generating prediction 102/1000...
# Generating prediction 103/1000...
# Generating prediction 104/1000...
# Generating prediction 105/1000...
# Generating prediction 106/1000...
# Generating prediction 107/1000...
# Generating prediction 108/1000...
# Generating prediction 109/1000...
# Generating prediction 110/1000...
# Generating prediction 111/1000...
# Generating prediction 112/1000...
# Generating prediction 113/1000...
# Generating prediction 114/1000...
# Generating prediction 115/1000...
# Generating prediction 116/1000...
# Generating prediction 117/1000...
# Generating prediction 118/1000...
# Generating prediction 119/1000...
# Generating prediction 120/1000...
# Generating prediction 121/1000...
# Generating prediction 122/1000...
# Generating prediction 123/1000...
# Generating prediction 124/1000...
# Generating prediction 125/1000...
# Generating prediction 126/1000...
# Generating prediction 127/1000...
# Generating prediction 128/1000...
# Generating prediction 129/1000...
# Generating prediction 130/1000...
# Generating prediction 131/1000...
# Generating prediction 132/1000...
# Generating prediction 133/1000...
# Generating prediction 134/1000...
# Generating prediction 135/1000...
# Generating prediction 136/1000...
# Generating prediction 137/1000...
# Generating prediction 138/1000...
# Generating prediction 139/1000...
# Generating prediction 140/1000...
# Generating prediction 141/1000...
# Generating prediction 142/1000...
# Generating prediction 143/1000...
# Generating prediction 144/1000...
# Generating prediction 145/1000...
# Generating prediction 146/1000...
# Generating prediction 147/1000...
# Generating prediction 148/1000...
# Generating prediction 149/1000...
# Generating prediction 150/1000...
# Generating prediction 151/1000...
# Generating prediction 152/1000...
# Generating prediction 153/1000...
# Generating prediction 154/1000...
# Generating prediction 155/1000...
# Generating prediction 156/1000...
# Generating prediction 157/1000...
# Generating prediction 158/1000...
# Generating prediction 159/1000...
# Generating prediction 160/1000...
# Generating prediction 161/1000...
# Generating prediction 162/1000...
# Generating prediction 163/1000...
# Generating prediction 164/1000...
# Generating prediction 165/1000...
# Generating prediction 166/1000...
# Generating prediction 167/1000...
# Generating prediction 168/1000...
# Generating prediction 169/1000...
# Generating prediction 170/1000...
# Generating prediction 171/1000...
# Generating prediction 172/1000...
# Generating prediction 173/1000...
# Generating prediction 174/1000...
# Generating prediction 175/1000...
# Generating prediction 176/1000...
# Generating prediction 177/1000...
# Generating prediction 178/1000...
# Generating prediction 179/1000...
# Generating prediction 180/1000...
# Generating prediction 181/1000...
# Generating prediction 182/1000...
# Generating prediction 183/1000...
# Generating prediction 184/1000...
# Generating prediction 185/1000...
# Generating prediction 186/1000...
# Generating prediction 187/1000...
# Generating prediction 188/1000...
# Generating prediction 189/1000...
# Generating prediction 190/1000...
# Generating prediction 191/1000...
# Generating prediction 192/1000...
# Generating prediction 193/1000...
# Generating prediction 194/1000...
# Generating prediction 195/1000...
# Generating prediction 196/1000...
# Generating prediction 197/1000...
# Generating prediction 198/1000...
# Generating prediction 199/1000...
# Generating prediction 200/1000...
# Generating prediction 201/1000...
# Generating prediction 202/1000...
# Generating prediction 203/1000...
# Generating prediction 204/1000...
# Generating prediction 205/1000...
# Generating prediction 206/1000...
# Generating prediction 207/1000...
# Generating prediction 208/1000...
# Generating prediction 209/1000...
# Generating prediction 210/1000...
# Generating prediction 211/1000...
# Generating prediction 212/1000...
# Generating prediction 213/1000...
# Generating prediction 214/1000...
# Generating prediction 215/1000...
# Generating prediction 216/1000...
# Generating prediction 217/1000...
# Generating prediction 218/1000...
# Generating prediction 219/1000...
# Generating prediction 220/1000...
# Generating prediction 221/1000...
# Generating prediction 222/1000...
# Generating prediction 223/1000...
# Generating prediction 224/1000...
# Generating prediction 225/1000...
# Generating prediction 226/1000...
# Generating prediction 227/1000...
# Generating prediction 228/1000...
# Generating prediction 229/1000...
# Generating prediction 230/1000...
# Generating prediction 231/1000...
# Generating prediction 232/1000...
# Generating prediction 233/1000...
# Generating prediction 234/1000...
# Generating prediction 235/1000...
# Generating prediction 236/1000...
# Generating prediction 237/1000...
# Generating prediction 238/1000...
# Generating prediction 239/1000...
# Generating prediction 240/1000...
# Generating prediction 241/1000...
# Generating prediction 242/1000...
# Generating prediction 243/1000...
# Generating prediction 244/1000...
# Generating prediction 245/1000...
# Generating prediction 246/1000...
# Generating prediction 247/1000...
# Generating prediction 248/1000...
# Generating prediction 249/1000...
# Generating prediction 250/1000...
# Generating prediction 251/1000...
# Generating prediction 252/1000...
# Generating prediction 253/1000...
# Generating prediction 254/1000...
# Generating prediction 255/1000...
# Generating prediction 256/1000...
# Generating prediction 257/1000...
# Generating prediction 258/1000...
# Generating prediction 259/1000...
# Generating prediction 260/1000...
# Generating prediction 261/1000...
# Generating prediction 262/1000...
# Generating prediction 263/1000...
# Generating prediction 264/1000...
# Generating prediction 265/1000...
# Generating prediction 266/1000...
# Generating prediction 267/1000...
# Generating prediction 268/1000...
# Generating prediction 269/1000...
# Generating prediction 270/1000...
# Generating prediction 271/1000...
# Generating prediction 272/1000...
# Generating prediction 273/1000...
# Generating prediction 274/1000...
# Generating prediction 275/1000...
# Generating prediction 276/1000...
# Generating prediction 277/1000...
# Generating prediction 278/1000...
# Generating prediction 279/1000...
# Generating prediction 280/1000...
# Generating prediction 281/1000...
# Generating prediction 282/1000...
# Generating prediction 283/1000...
# Generating prediction 284/1000...
# Generating prediction 285/1000...
# Generating prediction 286/1000...
# Generating prediction 287/1000...
# Generating prediction 288/1000...
# Generating prediction 289/1000...
# Generating prediction 290/1000...
# Generating prediction 291/1000...
# Generating prediction 292/1000...
# Generating prediction 293/1000...
# Generating prediction 294/1000...
# ^C

# %%
# !python inference_lora_qwen3_wolof.py \
  --model-choice qwen \
  --adapter auto \
  --category agriculture \
  --instruction "What are the symptoms of Tip over or Heart rot in banana plants?"
# Out:
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Adapter: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# `torch_dtype` is deprecated! Use `dtype` instead!
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|█| 311/311 [00:00<00:00, 722.04it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
#
# === Prompt ===
# Category: agriculture
# Instruction: What are the symptoms of Tip over or Heart rot in banana plants?
#
# === Model answer ===
# Symptoms of Tip Over or Heart Rot in Banana Plants include yellowing of leaves, wilting, and death of young leaves. The disease is more common during dry spells when waterlogging occurs at the base of the plant. Infected leaves may turn brown and shrivel up to 10 cm from the node. In severe cases, entire branches can be reduced by 50-70%.

# %%
#test local
# !python inference_lora_qwen3_wolof.py \
  --model-choice qwen \
  --adapter auto \
  --category agriculture \
  --instruction "asking regarding the time of sowing for maize as fodder crops"
# Out:
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Adapter: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 676.43it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# === Prompt ===
# Category: agriculture
# Instruction: asking regarding the time of sowing for maize as fodder crops
#
# === Model answer ===
# suggested to sow in the month of september- october

# %%
# !python inference_lora_qwen3_wolof.py \
  --model-choice qwen \
  --adapter "" \
  --instruction "How to control fungal wilt in brinjal?"
# Out:
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Adapter: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 687.62it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
#
# === Prompt ===
# Category: agriculture
# Instruction: How to control fungal wilt in brinjal?
#
# === Model answer ===
# Fungal wilt in Brinjal can be controlled by spraying Captafol or Mancozeb at a concentration of 0.2% for two days after transplanting the plants. This will help to suppress the growth of the fungus and prevent the spread of the disease within the field.

# %%
# !python inference_lora_qwen3_wolof.py \
  --model-choice qwen \
  --adapter auto \
  --category agriculture \
  --instruction "What is the pathogen responsible for Sigatoka disease in bananas?"
# Out:
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Adapter: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 686.61it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
#
# === Prompt ===
# Category: agriculture
# Instruction: What is the pathogen responsible for Sigatoka disease in bananas?
#
# === Model answer ===
# The pathogen is Xanthomonas axonopodis pv. manihotis, a Gram-negative, non-spore-forming, rod-shaped bacterium that is aerobic and pleiotropic. It infects banana plants through cuttings and spreads via wind-borne spores. The disease manifests with symptoms such as yellowish necrosis of leaves, stunted growth, and root rot.

# %%
# !python inference_lora_qwen3_wolof.py \
  --model-choice qwen \
  --adapter auto \
  --category agriculture \
  --instruction "How does Leaf spot disease spread in Sapota trees?"
# Out:
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Adapter: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 658.66it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# === Prompt ===
# Category: agriculture
# Instruction: How does Leaf spot disease spread in Sapota trees?
#
# === Model answer ===
# Leaf spot disease in Sapoots spreads through infected suckers, with secondary infections caused by fungi like Fusarium oxysporum f. sp. sapotae and Alternaria alternata. It also spreads through water splashes from infected leaves to healthy ones.

# %%
# !python inference_lora_qwen3_wolof.py \
  --model-choice qwen \
  --adapter auto \
  --category agriculture \
  --instruction "What is crop rotation?"
# Out:
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Adapter: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%|█| 311/311 [00:00<00:00, 683.10it/s, Materializing param=m
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
#
# === Prompt ===
# Category: agriculture
# Instruction: What is crop rotation?
#
# === Model answer ===
# Crop rotation involves planting different crops in the same area over a period of several months or years. This practice helps to break the cycle of disease and pest buildup, as each crop has a different nutrient and virus profile that it can attack.

# %%
from huggingface_hub import login

login("")

# %%
# !python push_to_hub.py --check-auth
# Out:
# Authenticated Hugging Face user: Mumphone

# %%
# !python push_to_hub.py \
  --repo-id Mumphone/agriculture-qwen3-lora \
  --model-choice qwen \
  --adapter-dir auto \
  --checkpoint best \
  --public
# Out:
# Authenticated Hugging Face user: Mumphone
# Model choice: qwen
# Base model: Qwen/Qwen3-0.6B
# Selected adapter source (best_adapter): /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/best_adapter
# Clean upload folder: /kaggle/working/agriculture_assistant/outputs/qwen3_0_6b_wolof_lora/hub_upload_adapter
# Repository visibility set to public.
# Uploading clean adapter files only.
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
# Processing Files (1 / 1)      :  22%|███           | 11.4MB / 51.8MB, 19.0MB/s
#
#
#   ...adapter_model.safetensors:   1%|▏             |  553kB / 40.4MB
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  23%|███▏          | 12.0MB / 51.8MB, 15.0MB/s
# New Data Upload               :   1%|▏             |  553kB / 40.4MB,  691kB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:   1%|▏             |  553kB / 40.4MB
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  25%|███▌          | 13.1MB / 51.8MB, 10.9MB/s
# New Data Upload               :   4%|▌             | 1.66MB / 40.4MB, 1.38MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  34%|████▋         | 17.5MB / 51.8MB, 12.5MB/s
# New Data Upload               :  15%|██            | 6.08MB / 40.4MB, 4.34MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  50%|██████▉       | 25.8MB / 51.8MB, 16.1MB/s
# New Data Upload               :  36%|████▉         | 14.4MB / 40.4MB, 8.99MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  66%|█████████▏    | 34.1MB / 51.8MB, 18.9MB/s
# New Data Upload               :  56%|███████▊      | 22.7MB / 40.4MB, 12.6MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  82%|███████████▍  | 42.4MB / 51.8MB, 21.2MB/s
# New Data Upload               :  77%|██████████▋   | 31.0MB / 40.4MB, 15.5MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  98%|█████████████▋| 50.7MB / 51.8MB, 23.0MB/s
# New Data Upload               :  97%|█████████████▌| 39.3MB / 40.4MB, 17.8MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      : 100%|█████████████▉| 51.8MB / 51.8MB, 21.6MB/s
# New Data Upload               : 100%|█████████████▉| 40.4MB / 40.4MB, 16.8MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|█████████████▉| 40.4MB / 40.4MB
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (2 / 2)      : 100%|██████████████| 51.8MB / 51.8MB, 18.5MB/s
# New Data Upload               : 100%|██████████████| 40.4MB / 40.4MB, 14.4MB/s
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|██████████████| 40.4MB / 40.4MB
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|██████████████| 40.4MB / 40.4MB
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|██████████████| 40.4MB / 40.4MB
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|██████████████| 40.4MB / 40.4MB
#
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (2 / 2)      : 100%|██████████████| 51.8MB / 51.8MB, 14.4MB/s
# New Data Upload               : 100%|██████████████| 40.4MB / 40.4MB, 11.2MB/s
#   ...ad_adapter/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#   ...adapter_model.safetensors: 100%|██████████████| 40.4MB / 40.4MB
# Uploaded to: https://huggingface.co/Mumphone/agriculture-qwen3-lora
